# %%
from focus_group import FocusGroup

focus_group = FocusGroup()

# %%
import matplotlib.pylab as plt

plt.plot(focus_group.systolic)
plt.plot(focus_group.diastolic)
plt.plot(focus_group.predicted)
plt.show()
